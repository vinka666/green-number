# %% [markdown]
# ## Configs

# %%
pip install scikit-learn pandas yfinance ta tqdm tables
# Out:
# Requirement already satisfied: scikit-learn in c:\users\alvin\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: pandas in c:\users\alvin\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: yfinance in c:\users\alvin\anaconda3\lib\site-packages (0.2.26)
# Requirement already satisfied: ta in c:\users\alvin\anaconda3\lib\site-packages (0.10.2)
# Requirement already satisfied: tqdm in c:\users\alvin\anaconda3\lib\site-packages (4.65.0)
# Requirement already satisfied: tables in c:\users\alvin\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\alvin\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\alvin\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\alvin\anaconda3\lib\site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in c:\users\alvin\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alvin\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alvin\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\alvin\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\alvin\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.31 in c:\users\alvin\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\alvin\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\alvin\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\alvin\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: html5lib>=1.1 in c:\users\alvin\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\alvin\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: colorama in c:\users\alvin\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\alvin\anaconda3\lib\site-packages (from tables) (2.8.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alvin\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\alvin\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\alvin\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: packaging in c:\users\alvin\anaconda3\lib\site-packages (from numexpr>=2.6.2->tables) (21.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alvin\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alvin\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alvin\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alvin\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\alvin\anaconda3\lib\site-packages (from packaging->numexpr>=2.6.2->tables) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alvin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alvin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alvin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alvin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alvin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alvin\anaconda3\lib\site-packages)

# %%
import warnings
from sklearn.model_selection import train_test_split
import pandas as pd
import yfinance as yf
import os, contextlib
import pandas as pd
from ta import add_all_ta_features
from tqdm import tqdm
import shutil
from os.path import isfile, join

warnings.filterwarnings('ignore')
offset = 0
limit = None
period = 'max' # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max

# %% [markdown]
# ## Download all NASDAQ traded symbols

# %%
data = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep='|')
data_clean = data[data['Test Issue'] == 'N']
symbols = data_clean['NASDAQ Symbol'].tolist()
print('total number of symbols traded = {}'.format(len(symbols)))
# Out:
# total number of symbols traded = 11267

# %% [markdown]
# ## Download Historic data and add_all_ta

# %%
! mkdir hist
# Out:
# A subdirectory or file hist already exists.

# %%
! mkdir crypto
# Out:
# A subdirectory or file crypto already exists.

# %% [markdown]
# ### Stocks

# %%
def optimize_dtypes(df):
    # This function will optimize the data types in a pandas DataFrame
    for col in df.columns:
        col_data = df[col]
        dn = col_data.dtype.name
        if dn == "object":
            df[col] = pd.to_numeric(col_data.astype("category").cat.codes, downcast="integer")
        elif dn == "bool":
            df[col] = col_data.astype("int8")
        elif dn.startswith("int") or (col_data.round() == col_data).all():
            df[col] = pd.to_numeric(col_data, downcast="integer")
        else:
            df[col] = pd.to_numeric(col_data, downcast='float')
    return df

def add_ticker_to_columns(df, ticker):
    # This function will add the ticker name to the column names
    df.columns = [f"{ticker}_{col}" for col in df.columns]
    return df

limit = limit if limit else len(symbols)
end = min(offset + limit, len(symbols))
is_valid = [False] * len(symbols)
window = 10  # replace this with the window size you're using for ATR

def add_all_ta_features_with_exceptions_and_cleanup(data):
    try:
        # Add all technical indicators
        data_with_ta = add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")
        
        # Identify columns to remove
        columns_to_remove = []
        for col in data_with_ta.columns:
            # Check for NaN values between the first 30 and last 30 rows
            if data_with_ta.iloc[30:-30][col].isna().any():
                columns_to_remove.append(col)
                
        # Remove identified columns
        data_with_ta.drop(columns=columns_to_remove, inplace=True)
        
        return data_with_ta
    
    except Exception as e:
        print(f"Error adding technical indicators. Error: {e}")
        return data

with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in tqdm(range(offset, end)):
            s = symbols[i]
            if not isinstance(s, str):  # Skip non-string symbols
                print(f"Invalid symbol: {s}. Skipping.")
                continue
            data = yf.download(s, period=period)
            if len(data) < 61:  # Skip if less than 61 lines of data
                print(f"Insufficient data for symbol: {s}. Skipping.")
                continue

            data = optimize_dtypes(data)  # Optimize the data types
            data = add_all_ta_features_with_exceptions_and_cleanup(data)  # Add technical indicators
            data = add_ticker_to_columns(data, s)  # Add the ticker to column names

            is_valid[i] = True
            data.to_hdf('hist/{}.h5'.format(s), key='df', mode='w')  # Save as HDF5

print('Total number of valid symbols downloaded = {}'.format(sum(is_valid)))
# Out:
#   0%|                                                                              | 5/11267 [00:15<6:57:56,  2.23s/it]
# 1 Failed download:
# ['AAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|                                                                              | 6/11267 [00:16<4:58:36,  1.59s/it]
# 1 Failed download:
# ['AAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|                                                                             | 12/11267 [00:21<2:30:26,  1.25it/s]
# 1 Failed download:
# ['AACT=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|                                                                             | 13/11267 [00:22<2:58:24,  1.05it/s]
# 1 Failed download:
# ['AACT+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|                                                                             | 17/11267 [00:29<6:06:11,  1.95s/it]
# 1 Failed download:
# ['AAIC-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|                                                                             | 18/11267 [00:29<4:33:02,  1.46s/it]
# 1 Failed download:
# ['AAIC-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|▏                                                                            | 21/11267 [00:33<4:37:38,  1.48s/it]
# 1 Failed download:
# ['AAM-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|▏                                                                            | 22/11267 [00:33<3:32:45,  1.14s/it]
# 1 Failed download:
# ['AAM-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|▎                                                                            | 54/11267 [01:47<6:08:35,  1.97s/it]
# 1 Failed download:
# ['ABR-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|▍                                                                            | 55/11267 [01:48<4:35:09,  1.47s/it]
# 1 Failed download:
# ['ABR-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   0%|▍                                                                            | 56/11267 [01:48<3:30:18,  1.13s/it]
# 1 Failed download:
# ['ABR-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▌                                                                            | 74/11267 [02:12<2:02:33,  1.52it/s]
# 1 Failed download:
# ['ACAQ=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▌                                                                            | 75/11267 [02:12<1:42:58,  1.81it/s]
# 1 Failed download:
# ['ACAQ+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▋                                                                            | 98/11267 [02:40<4:32:19,  1.46s/it]
# 1 Failed download:
# ['ACHR+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▊                                                                           | 116/11267 [03:19<6:35:29,  2.13s/it]
# 1 Failed download:
# ['ACP-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▊                                                                           | 118/11267 [03:23<6:42:53,  2.17s/it]
# 1 Failed download:
# ['ACR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▊                                                                           | 119/11267 [03:24<4:58:06,  1.60s/it]
# 1 Failed download:
# ['ACR-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▊                                                                           | 122/11267 [03:26<3:40:22,  1.19s/it]
# 1 Failed download:
# ['ACRO=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▊                                                                           | 123/11267 [03:27<2:52:28,  1.08it/s]
# 1 Failed download:
# ['ACRO+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|▉                                                                           | 144/11267 [04:07<9:41:26,  3.14s/it]
# 1 Failed download:
# ['ADC-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|█                                                                           | 153/11267 [04:20<4:32:13,  1.47s/it]
# 1 Failed download:
# ['ADEX=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   1%|█                                                                           | 154/11267 [04:20<3:27:56,  1.12s/it]
# 1 Failed download:
# ['ADEX+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▏                                                                          | 173/11267 [04:55<3:44:24,  1.21s/it]
# 1 Failed download:
# ['ADRT=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▎                                                                          | 201/11267 [05:55<9:10:31,  2.98s/it]
# 1 Failed download:
# ['AEL-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▎                                                                          | 202/11267 [05:55<6:42:39,  2.18s/it]
# 1 Failed download:
# ['AEL-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▍                                                                          | 211/11267 [06:14<6:03:50,  1.97s/it]
# 1 Failed download:
# ['AEON+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▍                                                                          | 219/11267 [06:31<4:24:08,  1.43s/it]
# 1 Failed download:
# ['AEVA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▊                                                                          | 268/11267 [07:51<7:22:53,  2.42s/it]
# 1 Failed download:
# ['AGM-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▊                                                                          | 269/11267 [07:51<5:27:42,  1.79s/it]
# 1 Failed download:
# ['AGM-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▊                                                                          | 270/11267 [07:51<4:05:43,  1.34s/it]
# 1 Failed download:
# ['AGM-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▊                                                                          | 271/11267 [07:52<3:09:12,  1.03s/it]
# 1 Failed download:
# ['AGM-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▊                                                                          | 272/11267 [07:52<2:28:00,  1.24it/s]
# 1 Failed download:
# ['AGM-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   2%|█▊                                                                          | 273/11267 [07:52<2:01:45,  1.50it/s]
# 1 Failed download:
# ['AGM.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 301/11267 [08:36<5:43:24,  1.88s/it]
# 1 Failed download:
# ['AHH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 303/11267 [08:37<3:37:34,  1.19s/it]
# 1 Failed download:
# ['AHL-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 304/11267 [08:37<2:48:51,  1.08it/s]
# 1 Failed download:
# ['AHL-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 305/11267 [08:37<2:13:49,  1.37it/s]
# 1 Failed download:
# ['AHL-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 308/11267 [08:41<3:55:29,  1.29s/it]
# 1 Failed download:
# ['AHT-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 309/11267 [08:43<4:07:01,  1.35s/it]
# 1 Failed download:
# ['AHT-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 310/11267 [08:43<3:09:17,  1.04s/it]
# 1 Failed download:
# ['AHT-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 311/11267 [08:43<2:29:45,  1.22it/s]
# 1 Failed download:
# ['AHT-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██                                                                          | 312/11267 [08:44<2:00:19,  1.52it/s]
# 1 Failed download:
# ['AHT-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██▏                                                                         | 324/11267 [09:00<7:56:37,  2.61s/it]
# 1 Failed download:
# ['AIG-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██▍                                                                         | 362/11267 [10:21<4:37:10,  1.53s/it]
# 1 Failed download:
# ['AKO.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██▍                                                                         | 363/11267 [10:21<3:30:12,  1.16s/it]
# 1 Failed download:
# ['AKO.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   3%|██▌                                                                         | 371/11267 [10:34<4:19:57,  1.43s/it]
# 1 Failed download:
# ['AL-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|██▋                                                                         | 397/11267 [11:29<8:37:10,  2.85s/it]
# 1 Failed download:
# ['ALL-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|██▋                                                                         | 398/11267 [11:29<6:19:00,  2.09s/it]
# 1 Failed download:
# ['ALL-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|██▋                                                                         | 399/11267 [11:29<4:42:50,  1.56s/it]
# 1 Failed download:
# ['ALL-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|██▋                                                                         | 400/11267 [11:29<3:34:10,  1.18s/it]
# 1 Failed download:
# ['ALL-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|██▋                                                                         | 403/11267 [11:32<3:01:32,  1.00s/it]
# 1 Failed download:
# ['ALLG+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|██▉                                                                         | 427/11267 [12:12<3:34:26,  1.19s/it]
# 1 Failed download:
# ['ALTG-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|██▉                                                                         | 437/11267 [12:25<3:50:15,  1.28s/it]
# 1 Failed download:
# ['ALUR+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|███                                                                         | 447/11267 [12:45<5:58:35,  1.99s/it]
# 1 Failed download:
# ['AMAL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1924-09-22 -> 2023-08-30)')
#   4%|███                                                                         | 457/11267 [13:08<4:36:25,  1.53s/it]
# 1 Failed download:
# ['AMBI+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|███                                                                         | 460/11267 [13:10<3:06:34,  1.04s/it]
# 1 Failed download:
# ['AMBP+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|███▏                                                                       | 472/11267 [13:44<10:06:01,  3.37s/it]
# 1 Failed download:
# ['AMH-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|███▏                                                                        | 473/11267 [13:45<7:19:30,  2.44s/it]
# 1 Failed download:
# ['AMH-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   4%|███▎                                                                        | 495/11267 [14:20<2:55:00,  1.03it/s]
# 1 Failed download:
# ['AMPX+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   5%|███▊                                                                        | 562/11267 [16:50<9:23:09,  3.16s/it]
# 1 Failed download:
# ['AP+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   5%|███▊                                                                        | 569/11267 [17:00<4:36:17,  1.55s/it]
# 1 Failed download:
# ['APCA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   5%|███▊                                                                        | 570/11267 [17:00<3:29:13,  1.17s/it]
# 1 Failed download:
# ['APCA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   5%|███▉                                                                        | 579/11267 [17:16<4:58:44,  1.68s/it]
# 1 Failed download:
# ['APGB=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   5%|███▉                                                                        | 580/11267 [17:17<3:44:58,  1.26s/it]
# 1 Failed download:
# ['APGB+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   5%|████                                                                        | 595/11267 [17:34<4:12:29,  1.42s/it]
# 1 Failed download:
# ['APO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   6%|████▍                                                                       | 662/11267 [19:18<8:11:38,  2.78s/it]
# 1 Failed download:
# ['ARGO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   6%|████▋                                                                       | 694/11267 [20:13<5:06:58,  1.74s/it]
# 1 Failed download:
# ['ARR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   6%|████▊                                                                       | 716/11267 [20:57<9:53:00,  3.37s/it]
# 1 Failed download:
# ['ASB-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   6%|████▊                                                                       | 717/11267 [20:58<7:12:06,  2.46s/it]
# 1 Failed download:
# ['ASB-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▏                                                                      | 775/11267 [22:41<2:45:10,  1.06it/s]
# 1 Failed download:
# ['ATAQ=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▏                                                                      | 777/11267 [22:42<2:05:20,  1.39it/s]
# 1 Failed download:
# ['ATCO-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▏                                                                      | 778/11267 [22:42<1:43:28,  1.69it/s]
# 1 Failed download:
# ['ATCO-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 779/11267 [22:42<1:28:13,  1.98it/s]
# 1 Failed download:
# ['ATCO-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 783/11267 [22:47<2:58:32,  1.02s/it]
# 1 Failed download:
# ['ATEK=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 784/11267 [22:47<2:21:13,  1.24it/s]
# 1 Failed download:
# ['ATEK+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 790/11267 [22:57<6:00:11,  2.06s/it]
# 1 Failed download:
# ['ATH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 791/11267 [22:57<4:30:55,  1.55s/it]
# 1 Failed download:
# ['ATH-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 792/11267 [22:57<3:26:48,  1.18s/it]
# 1 Failed download:
# ['ATH-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 793/11267 [22:58<3:02:40,  1.05s/it]
# 1 Failed download:
# ['ATH-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▎                                                                      | 794/11267 [22:58<2:24:12,  1.21it/s]
# 1 Failed download:
# ['ATH-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   7%|█████▋                                                                      | 838/11267 [24:28<9:06:02,  3.14s/it]
# 1 Failed download:
# ['AUB-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   8%|█████▋                                                                      | 847/11267 [24:42<5:04:09,  1.75s/it]
# 1 Failed download:
# ['AULT-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   8%|██████▏                                                                    | 935/11267 [27:33<12:41:10,  4.42s/it]
# 1 Failed download:
# ['AXS-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▍                                                                    | 961/11267 [28:40<10:15:39,  3.58s/it]
# 1 Failed download:
# ['BAC-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▍                                                                     | 962/11267 [28:40<7:29:43,  2.62s/it]
# 1 Failed download:
# ['BAC-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▍                                                                     | 963/11267 [28:40<5:30:48,  1.93s/it]
# 1 Failed download:
# ['BAC-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▌                                                                     | 964/11267 [28:41<4:06:54,  1.44s/it]
# 1 Failed download:
# ['BAC-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▌                                                                     | 965/11267 [28:41<3:08:04,  1.10s/it]
# 1 Failed download:
# ['BAC-M']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▌                                                                     | 966/11267 [28:41<2:27:55,  1.16it/s]
# 1 Failed download:
# ['BAC-N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▌                                                                     | 967/11267 [28:41<2:00:26,  1.43it/s]
# 1 Failed download:
# ['BAC-O']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▌                                                                     | 968/11267 [28:42<1:42:13,  1.68it/s]
# 1 Failed download:
# ['BAC-P']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▌                                                                     | 969/11267 [28:42<1:27:46,  1.96it/s]
# 1 Failed download:
# ['BAC-Q']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▌                                                                     | 970/11267 [28:42<1:17:24,  2.22it/s]
# 1 Failed download:
# ['BAC-S']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▋                                                                     | 995/11267 [29:26<4:25:19,  1.55s/it]
# 1 Failed download:
# ['BARK+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▋                                                                    | 1006/11267 [29:44<5:11:54,  1.82s/it]
# 1 Failed download:
# ['BBAI+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▊                                                                   | 1046/11267 [30:58<11:47:06,  4.15s/it]
# 1 Failed download:
# ['BC-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▉                                                                    | 1047/11267 [30:58<8:30:49,  3.00s/it]
# 1 Failed download:
# ['BC-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#   9%|██████▉                                                                    | 1048/11267 [30:58<6:12:52,  2.19s/it]
# 1 Failed download:
# ['BC-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▍                                                                   | 1116/11267 [33:11<5:17:14,  1.88s/it]
# 1 Failed download:
# ['BEP-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▍                                                                   | 1126/11267 [33:19<2:27:08,  1.15it/s]
# 1 Failed download:
# ['BF.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▌                                                                   | 1127/11267 [33:20<2:01:02,  1.40it/s]
# 1 Failed download:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1924-09-22 -> 2023-08-30)')
#  10%|███████▌                                                                   | 1129/11267 [33:20<1:42:25,  1.65it/s]
# 1 Failed download:
# ['BFAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▌                                                                   | 1130/11267 [33:21<1:27:39,  1.93it/s]
# 1 Failed download:
# ['BFAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▌                                                                   | 1142/11267 [33:40<5:06:04,  1.81s/it]
# 1 Failed download:
# ['BFLY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▋                                                                   | 1149/11267 [33:48<4:44:58,  1.69s/it]
# 1 Failed download:
# ['BFS-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▋                                                                   | 1150/11267 [33:49<3:35:51,  1.28s/it]
# 1 Failed download:
# ['BFS-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  10%|███████▊                                                                   | 1172/11267 [34:36<8:01:27,  2.86s/it]
# 1 Failed download:
# ['BH.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|███████▉                                                                   | 1188/11267 [35:05<3:06:47,  1.11s/it]
# 1 Failed download:
# ['BHIL+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|███████▉                                                                   | 1194/11267 [35:19<6:52:06,  2.45s/it]
# 1 Failed download:
# ['BHR-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|███████▉                                                                   | 1195/11267 [35:20<5:03:21,  1.81s/it]
# 1 Failed download:
# ['BHR-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|████████                                                                   | 1218/11267 [35:58<6:31:01,  2.33s/it]
# 1 Failed download:
# ['BIO.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1924-09-22 -> 2023-08-30)')
#  11%|████████▏                                                                  | 1227/11267 [36:11<4:31:36,  1.62s/it]
# 1 Failed download:
# ['BIP-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|████████▏                                                                  | 1228/11267 [36:11<3:24:58,  1.23s/it]
# 1 Failed download:
# ['BIP-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|████████▏                                                                  | 1237/11267 [36:21<3:37:29,  1.30s/it]
# 1 Failed download:
# ['BITE=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|████████▏                                                                  | 1238/11267 [36:21<2:48:34,  1.01s/it]
# 1 Failed download:
# ['BITE+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|████████▍                                                                  | 1274/11267 [37:22<7:28:57,  2.70s/it]
# 1 Failed download:
# ['BKKT+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|████████▌                                                                  | 1285/11267 [37:45<5:40:25,  2.05s/it]
# 1 Failed download:
# ['BKSY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|████████▊                                                                  | 1331/11267 [39:02<3:24:51,  1.24s/it]
# 1 Failed download:
# ['BLUA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|████████▊                                                                  | 1332/11267 [39:03<2:37:48,  1.05it/s]
# 1 Failed download:
# ['BLUA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|████████▉                                                                  | 1340/11267 [39:18<4:48:17,  1.74s/it]
# 1 Failed download:
# ['BMAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|████████▉                                                                  | 1341/11267 [39:19<3:56:10,  1.43s/it]
# 1 Failed download:
# ['BMAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|████████▉                                                                  | 1350/11267 [39:34<7:28:41,  2.71s/it]
# 1 Failed download:
# ['BML-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|████████▉                                                                  | 1351/11267 [39:34<5:31:33,  2.01s/it]
# 1 Failed download:
# ['BML-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|████████▉                                                                  | 1352/11267 [39:34<4:08:17,  1.50s/it]
# 1 Failed download:
# ['BML-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|█████████                                                                  | 1353/11267 [39:35<3:10:02,  1.15s/it]
# 1 Failed download:
# ['BML-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|█████████                                                                  | 1361/11267 [39:52<6:29:27,  2.36s/it]
# 1 Failed download:
# ['BMTX+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|█████████▏                                                                 | 1377/11267 [40:21<2:39:47,  1.03it/s]
# 1 Failed download:
# ['BNIXR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  12%|█████████▎                                                                 | 1395/11267 [40:44<4:22:04,  1.59s/it]
# 1 Failed download:
# ['BOAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|█████████▎                                                                 | 1396/11267 [40:44<3:19:55,  1.22s/it]
# 1 Failed download:
# ['BOAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|█████████▎                                                                 | 1404/11267 [40:51<2:54:21,  1.06s/it]
# 1 Failed download:
# ['BODY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|█████████▎                                                                 | 1408/11267 [41:00<6:23:19,  2.33s/it]
# 1 Failed download:
# ['BOH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  13%|█████████▋                                                                 | 1454/11267 [42:21<3:58:52,  1.46s/it]
# 1 Failed download:
# ['BRD=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  13%|█████████▋                                                                 | 1455/11267 [42:22<3:02:48,  1.12s/it]
# 1 Failed download:
# ['BRD+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  13%|█████████▋                                                                 | 1458/11267 [42:24<2:25:50,  1.12it/s]
# 1 Failed download:
# ['BRDS+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  13%|█████████▊                                                                 | 1467/11267 [42:39<7:42:26,  2.83s/it]
# 1 Failed download:
# ['BRK.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  13%|█████████▊                                                                 | 1468/11267 [42:39<5:38:22,  2.07s/it]
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  14%|██████████▋                                                                | 1600/11267 [45:57<2:54:06,  1.08s/it]
# 1 Failed download:
# ['BURU+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  14%|██████████▋                                                                | 1613/11267 [46:19<4:55:27,  1.84s/it]
# 1 Failed download:
# ['BW-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  15%|██████████▉                                                                | 1648/11267 [47:22<6:06:41,  2.29s/it]
# 1 Failed download:
# ['BYN=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  15%|██████████▉                                                                | 1649/11267 [47:22<4:30:45,  1.69s/it]
# 1 Failed download:
# ['BYN+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  15%|███████████                                                                | 1669/11267 [47:52<8:40:17,  3.25s/it]
# 1 Failed download:
# ['C-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  15%|███████████                                                                | 1670/11267 [47:53<6:18:25,  2.37s/it]
# 1 Failed download:
# ['C-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  15%|███████████                                                                | 1671/11267 [47:53<4:40:45,  1.76s/it]
# 1 Failed download:
# ['C-N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  15%|███████████▏                                                               | 1682/11267 [48:22<9:25:34,  3.54s/it]
# 1 Failed download:
# ['CADE-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  15%|███████████▎                                                               | 1708/11267 [49:21<3:46:52,  1.42s/it]
# 1 Failed download:
# ['CANO+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  16%|███████████▉                                                               | 1799/11267 [52:54<4:56:19,  1.88s/it]
# 1 Failed download:
# ['CCV=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  16%|███████████▉                                                               | 1800/11267 [52:55<3:41:11,  1.40s/it]
# 1 Failed download:
# ['CCV+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  16%|███████████▉                                                               | 1802/11267 [52:56<2:35:42,  1.01it/s]
# 1 Failed download:
# ['CCVI=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  16%|████████████                                                               | 1803/11267 [52:56<2:03:42,  1.27it/s]
# 1 Failed download:
# ['CCVI+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  16%|████████████                                                               | 1820/11267 [53:22<6:56:35,  2.65s/it]
# 1 Failed download:
# ['CDR-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  16%|████████████                                                               | 1821/11267 [53:22<5:06:16,  1.95s/it]
# 1 Failed download:
# ['CDR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  16%|████████████▎                                                              | 1845/11267 [54:06<4:07:10,  1.57s/it]
# 1 Failed download:
# ['CELG^']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  17%|████████████▍                                                              | 1860/11267 [54:36<6:28:23,  2.48s/it]
# 1 Failed download:
# ['CEQP-']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  17%|████████████▌                                                              | 1890/11267 [55:25<3:40:06,  1.41s/it]
# 1 Failed download:
# ['CFG-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  17%|████████████▌                                                              | 1891/11267 [55:26<3:04:13,  1.18s/it]
# 1 Failed download:
# ['CFG-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  17%|████████████▋                                                              | 1899/11267 [55:38<6:15:35,  2.41s/it]
# 1 Failed download:
# ['CFR-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  17%|█████████████                                                              | 1963/11267 [57:31<6:09:24,  2.38s/it]
# 1 Failed download:
# ['CHMI-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  17%|█████████████                                                              | 1964/11267 [57:32<4:35:57,  1.78s/it]
# 1 Failed download:
# ['CHMI-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  18%|█████████████▎                                                             | 1998/11267 [58:47<6:21:39,  2.47s/it]
# 1 Failed download:
# ['CIG.C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  18%|█████████████▎                                                             | 2004/11267 [59:03<6:56:10,  2.70s/it]
# 1 Failed download:
# ['CIM-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  18%|█████████████▎                                                             | 2005/11267 [59:03<5:05:17,  1.98s/it]
# 1 Failed download:
# ['CIM-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  18%|█████████████▎                                                             | 2006/11267 [59:04<3:46:47,  1.47s/it]
# 1 Failed download:
# ['CIM-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  18%|█████████████▎                                                             | 2007/11267 [59:04<2:52:38,  1.12s/it]
# 1 Failed download:
# ['CIM-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  18%|█████████████▍                                                             | 2013/11267 [59:13<3:21:17,  1.31s/it]
# 1 Failed download:
# ['CIO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  18%|█████████████▏                                                           | 2043/11267 [1:00:06<3:45:02,  1.46s/it]
# 1 Failed download:
# ['CLDT-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▌                                                           | 2096/11267 [1:01:24<3:08:22,  1.23s/it]
# 1 Failed download:
# ['CLVT-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▊                                                           | 2134/11267 [1:02:48<3:28:19,  1.37s/it]
# 1 Failed download:
# ['CMRE-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▊                                                           | 2135/11267 [1:02:49<2:55:49,  1.16s/it]
# 1 Failed download:
# ['CMRE-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▊                                                           | 2136/11267 [1:02:50<3:02:47,  1.20s/it]
# 1 Failed download:
# ['CMRE-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▊                                                           | 2137/11267 [1:02:51<2:21:44,  1.07it/s]
# 1 Failed download:
# ['CMRE-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▊                                                           | 2140/11267 [1:02:59<6:30:47,  2.57s/it]
# 1 Failed download:
# ['CMS-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▊                                                           | 2141/11267 [1:02:59<4:48:15,  1.90s/it]
# 1 Failed download:
# ['CMS-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▉                                                           | 2155/11267 [1:03:33<5:02:58,  1.99s/it]
# 1 Failed download:
# ['CNDA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▉                                                           | 2156/11267 [1:03:33<3:47:08,  1.50s/it]
# 1 Failed download:
# ['CNDA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▉                                                           | 2158/11267 [1:03:34<2:31:29,  1.00it/s]
# 1 Failed download:
# ['CNDB=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|█████████████▉                                                           | 2159/11267 [1:03:34<2:04:39,  1.22it/s]
# 1 Failed download:
# ['CNDB+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  19%|██████████████                                                           | 2177/11267 [1:04:09<7:27:39,  2.95s/it]
# 1 Failed download:
# ['CNO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2202/11267 [1:05:03<5:27:28,  2.17s/it]
# 1 Failed download:
# ['CODI-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2203/11267 [1:05:04<4:04:28,  1.62s/it]
# 1 Failed download:
# ['CODI-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2204/11267 [1:05:04<3:06:29,  1.23s/it]
# 1 Failed download:
# ['CODI-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2210/11267 [1:05:12<4:15:19,  1.69s/it]
# 1 Failed download:
# ['COF-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2211/11267 [1:05:12<3:16:13,  1.30s/it]
# 1 Failed download:
# ['COF-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2212/11267 [1:05:12<2:31:07,  1.00s/it]
# 1 Failed download:
# ['COF-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2213/11267 [1:05:13<1:59:08,  1.27it/s]
# 1 Failed download:
# ['COF-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▎                                                          | 2214/11267 [1:05:13<1:39:49,  1.51it/s]
# 1 Failed download:
# ['COF-N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▌                                                          | 2253/11267 [1:06:32<5:16:33,  2.11s/it]
# 1 Failed download:
# ['CORR-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▊                                                          | 2288/11267 [1:08:05<6:48:30,  2.73s/it]
# 1 Failed download:
# ['CPTK=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▉                                                          | 2303/11267 [1:08:24<2:40:06,  1.07s/it]
# 1 Failed download:
# ['CRD.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  20%|██████████████▉                                                          | 2304/11267 [1:08:24<2:05:39,  1.19it/s]
# 1 Failed download:
# ['CRD.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  21%|███████████████▎                                                         | 2372/11267 [1:10:58<6:54:59,  2.80s/it]
# 1 Failed download:
# ['CSR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  21%|███████████████▍                                                         | 2378/11267 [1:11:03<2:46:46,  1.13s/it]
# 1 Failed download:
# ['CSTA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  21%|███████████████▍                                                         | 2379/11267 [1:11:05<2:55:45,  1.19s/it]
# 1 Failed download:
# ['CSTA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  21%|███████████████▍                                                         | 2390/11267 [1:11:30<6:05:43,  2.47s/it]
# 1 Failed download:
# ['CTA-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  21%|███████████████▍                                                         | 2391/11267 [1:11:30<4:30:24,  1.83s/it]
# 1 Failed download:
# ['CTA-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  21%|███████████████▌                                                         | 2411/11267 [1:12:14<6:23:08,  2.60s/it]
# 1 Failed download:
# ['CTO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  21%|███████████████▋                                                         | 2413/11267 [1:12:15<4:11:42,  1.71s/it]
# 1 Failed download:
# ['CTOS+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|███████████████▋                                                         | 2423/11267 [1:12:41<5:45:56,  2.35s/it]
# 1 Failed download:
# ['CTV+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|███████████████▋                                                         | 2430/11267 [1:12:54<5:15:10,  2.14s/it]
# 1 Failed download:
# ['CUBI-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|███████████████▊                                                         | 2431/11267 [1:12:54<3:53:25,  1.59s/it]
# 1 Failed download:
# ['CUBI-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|███████████████▉                                                         | 2452/11267 [1:13:38<6:19:32,  2.58s/it]
# 1 Failed download:
# ['CVE+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|███████████████▉                                                         | 2459/11267 [1:13:49<3:35:39,  1.47s/it]
# 1 Failed download:
# ['CVII=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|███████████████▉                                                         | 2460/11267 [1:13:49<2:44:46,  1.12s/it]
# 1 Failed download:
# ['CVII+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|████████████████                                                         | 2488/11267 [1:14:57<4:17:37,  1.76s/it]
# 1 Failed download:
# ['CWEN.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|████████████████▏                                                        | 2497/11267 [1:15:16<6:01:02,  2.47s/it]
# 1 Failed download:
# ['CXAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|████████████████▏                                                        | 2498/11267 [1:15:17<4:29:13,  1.84s/it]
# 1 Failed download:
# ['CXAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  23%|████████████████▋                                                        | 2582/11267 [1:17:50<3:56:11,  1.63s/it]
# 1 Failed download:
# ['DBRG-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  23%|████████████████▋                                                        | 2583/11267 [1:17:50<2:59:02,  1.24s/it]
# 1 Failed download:
# ['DBRG-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  23%|████████████████▋                                                        | 2584/11267 [1:17:51<2:17:39,  1.05it/s]
# 1 Failed download:
# ['DBRG-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  23%|████████████████▊                                                        | 2589/11267 [1:17:55<2:08:48,  1.12it/s]
# 1 Failed download:
# ['DC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  23%|████████████████▊                                                        | 2600/11267 [1:18:15<5:45:39,  2.39s/it]
# 1 Failed download:
# ['DCP-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|█████████████████▉                                                       | 2772/11267 [1:23:06<5:44:32,  2.43s/it]
# 1 Failed download:
# ['DLNG-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|█████████████████▉                                                       | 2773/11267 [1:23:06<4:13:13,  1.79s/it]
# 1 Failed download:
# ['DLNG-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|█████████████████▉                                                       | 2777/11267 [1:23:13<4:28:07,  1.89s/it]
# 1 Failed download:
# ['DLR-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|█████████████████▉                                                       | 2778/11267 [1:23:13<3:23:06,  1.44s/it]
# 1 Failed download:
# ['DLR-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|██████████████████                                                       | 2779/11267 [1:23:13<2:34:48,  1.09s/it]
# 1 Failed download:
# ['DLR-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|██████████████████▏                                                      | 2805/11267 [1:23:55<2:56:15,  1.25s/it]
# 1 Failed download:
# ['DMYY=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|██████████████████▏                                                      | 2806/11267 [1:23:55<2:15:38,  1.04it/s]
# 1 Failed download:
# ['DMYY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|██████████████████▏                                                      | 2808/11267 [1:23:56<1:47:22,  1.31it/s]
# 1 Failed download:
# ['DNA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  25%|██████████████████▍                                                      | 2854/11267 [1:25:16<4:59:16,  2.13s/it]
# 1 Failed download:
# ['DRH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  26%|██████████████████▋                                                      | 2875/11267 [1:25:50<2:45:11,  1.18s/it]
# 1 Failed download:
# ['DSAQ=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  26%|██████████████████▊                                                      | 2895/11267 [1:26:30<5:56:16,  2.55s/it]
# 1 Failed download:
# ['DSX-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  26%|██████████████████▉                                                      | 2924/11267 [1:27:14<5:29:42,  2.37s/it]
# 1 Failed download:
# ['DUK-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  26%|███████████████████▏                                                     | 2964/11267 [1:28:13<6:15:45,  2.72s/it]
# 1 Failed download:
# ...
# 1 Failed download:
# ['TDW+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  87%|███████████████████████████████████████████████████████████████▊         | 9845/11267 [4:50:20<1:06:16,  2.80s/it]
# 1 Failed download:
# ['TFC-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  87%|█████████████████████████████████████████████████████████████████▌         | 9846/11267 [4:50:20<48:27,  2.05s/it]
# 1 Failed download:
# ['TFC-O']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  87%|█████████████████████████████████████████████████████████████████▌         | 9847/11267 [4:50:20<35:54,  1.52s/it]
# 1 Failed download:
# ['TFC-R']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  88%|█████████████████████████████████████████████████████████████████▋         | 9868/11267 [4:50:50<40:00,  1.72s/it]
# 1 Failed download:
# ['TGH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  88%|█████████████████████████████████████████████████████████████████▋         | 9869/11267 [4:50:51<30:07,  1.29s/it]
# 1 Failed download:
# ['TGH-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  89%|██████████████████████████████████████████████████████████████████▌        | 9997/11267 [4:54:09<39:37,  1.87s/it]
# 1 Failed download:
# ['TNP-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  89%|██████████████████████████████████████████████████████████████████▌        | 9998/11267 [4:54:09<29:44,  1.41s/it]
# 1 Failed download:
# ['TNP-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  89%|█████████████████████████████████████████████████████████████████▉        | 10048/11267 [4:55:43<56:43,  2.79s/it]
# 1 Failed download:
# ['TRCA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  89%|██████████████████████████████████████████████████████████████████        | 10049/11267 [4:55:43<41:26,  2.04s/it]
# 1 Failed download:
# ['TRCA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  89%|██████████████████████████████████████████████████████████████████        | 10063/11267 [4:56:04<25:38,  1.28s/it]
# 1 Failed download:
# ['TRIS=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  89%|██████████████████████████████████████████████████████████████████        | 10064/11267 [4:56:05<19:47,  1.01it/s]
# 1 Failed download:
# ['TRIS+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10088/11267 [4:56:48<39:06,  1.99s/it]
# 1 Failed download:
# ['TRTL=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10089/11267 [4:56:48<29:04,  1.48s/it]
# 1 Failed download:
# ['TRTL+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10091/11267 [4:56:51<27:11,  1.39s/it]
# 1 Failed download:
# ['TRTN-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10092/11267 [4:56:51<20:45,  1.06s/it]
# 1 Failed download:
# ['TRTN-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10093/11267 [4:56:51<16:11,  1.21it/s]
# 1 Failed download:
# ['TRTN-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10094/11267 [4:56:51<12:58,  1.51it/s]
# 1 Failed download:
# ['TRTN-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10095/11267 [4:56:52<10:50,  1.80it/s]
# 1 Failed download:
# ['TRTN-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▎       | 10097/11267 [4:56:53<13:12,  1.48it/s]
# 1 Failed download:
# ['TRTX-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▉       | 10184/11267 [4:59:17<30:57,  1.72s/it]
# 1 Failed download:
# ['TWO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▉       | 10185/11267 [4:59:17<23:14,  1.29s/it]
# 1 Failed download:
# ['TWO-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  90%|██████████████████████████████████████████████████████████████████▉       | 10186/11267 [4:59:18<17:47,  1.01it/s]
# 1 Failed download:
# ['TWO-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  91%|██████████████████████████████████████████████████████████████████▉       | 10199/11267 [4:59:41<46:01,  2.59s/it]
# 1 Failed download:
# ['TY-']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  91%|███████████████████████████████████████████████████████████████████▍      | 10270/11267 [5:01:41<35:43,  2.15s/it]
# 1 Failed download:
# ['UHAL.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1924-09-22 -> 2023-08-30)')
#  91%|███████████████████████████████████████████████████████████████████▋      | 10300/11267 [5:02:34<37:16,  2.31s/it]
# 1 Failed download:
# ['UMH-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  92%|███████████████████████████████████████████████████████████████████▊      | 10326/11267 [5:03:19<18:46,  1.20s/it]
# 1 Failed download:
# ['UPH+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  92%|████████████████████████████████████████████████████████████████████      | 10357/11267 [5:04:10<43:22,  2.86s/it]
# 1 Failed download:
# ['USB-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  92%|████████████████████████████████████████████████████████████████████      | 10358/11267 [5:04:10<31:40,  2.09s/it]
# 1 Failed download:
# ['USB-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  92%|████████████████████████████████████████████████████████████████████      | 10359/11267 [5:04:11<23:26,  1.55s/it]
# 1 Failed download:
# ['USB-P']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  92%|████████████████████████████████████████████████████████████████████      | 10360/11267 [5:04:11<17:48,  1.18s/it]
# 1 Failed download:
# ['USB-Q']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  92%|████████████████████████████████████████████████████████████████████      | 10361/11267 [5:04:11<13:52,  1.09it/s]
# 1 Failed download:
# ['USB-R']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  92%|████████████████████████████████████████████████████████████████████      | 10362/11267 [5:04:12<12:29,  1.21it/s]
# 1 Failed download:
# ['USB-S']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  93%|████████████████████████████████████████████████████████████████████▌     | 10438/11267 [5:06:06<26:01,  1.88s/it]
# 1 Failed download:
# ['UWMC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  93%|████████████████████████████████████████████████████████████████████▋     | 10453/11267 [5:06:25<15:45,  1.16s/it]
# 1 Failed download:
# ['VAL+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  93%|████████████████████████████████████████████████████████████████████▉     | 10493/11267 [5:07:26<12:35,  1.02it/s]
# 1 Failed download:
# ['VCXB=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  93%|████████████████████████████████████████████████████████████████████▉     | 10494/11267 [5:07:27<09:55,  1.30it/s]
# 1 Failed download:
# ['VCXB+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▎    | 10548/11267 [5:08:47<23:52,  1.99s/it]
# 1 Failed download:
# ['VHAQ^']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▎    | 10549/11267 [5:08:48<17:51,  1.49s/it]
# 1 Failed download:
# ['VHAQ=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▎    | 10550/11267 [5:08:48<13:33,  1.13s/it]
# 1 Failed download:
# ['VHAQ+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▋    | 10602/11267 [5:10:05<15:13,  1.37s/it]
# 1 Failed download:
# ['VLD+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▋    | 10605/11267 [5:10:10<17:42,  1.61s/it]
# 1 Failed download:
# ['VLN+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▊    | 10635/11267 [5:11:05<24:38,  2.34s/it]
# 1 Failed download:
# ['VNO-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▊    | 10636/11267 [5:11:06<18:09,  1.73s/it]
# 1 Failed download:
# ['VNO-M']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▊    | 10637/11267 [5:11:06<13:47,  1.31s/it]
# 1 Failed download:
# ['VNO-N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  94%|█████████████████████████████████████████████████████████████████████▊    | 10638/11267 [5:11:06<10:31,  1.00s/it]
# 1 Failed download:
# ['VNO-O']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  95%|██████████████████████████████████████████████████████████████████████    | 10662/11267 [5:11:47<18:08,  1.80s/it]
# 1 Failed download:
# ['VOYA-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  95%|██████████████████████████████████████████████████████████████████████▎   | 10710/11267 [5:13:02<13:33,  1.46s/it]
# 1 Failed download:
# ['VST+A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|██████████████████████████████████████████████████████████████████████▊   | 10775/11267 [5:14:53<15:36,  1.90s/it]
# 1 Failed download:
# ['WAL-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|██████████████████████████████████████████████████████████████████████▉   | 10797/11267 [5:15:27<14:38,  1.87s/it]
# 1 Failed download:
# ['WBS-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|██████████████████████████████████████████████████████████████████████▉   | 10798/11267 [5:15:28<11:01,  1.41s/it]
# 1 Failed download:
# ['WBS-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|██████████████████████████████████████████████████████████████████████▉   | 10800/11267 [5:15:29<07:55,  1.02s/it]
# 1 Failed download:
# ['WBX+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|██████████████████████████████████████████████████████████████████████▉   | 10803/11267 [5:15:32<09:49,  1.27s/it]
# 1 Failed download:
# ['WCC-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████   | 10826/11267 [5:16:09<08:42,  1.18s/it]
# 1 Failed download:
# ['WEL=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████   | 10827/11267 [5:16:09<06:47,  1.08it/s]
# 1 Failed download:
# ['WEL+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10839/11267 [5:16:35<19:21,  2.71s/it]
# 1 Failed download:
# ['WFC-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10840/11267 [5:16:36<14:08,  1.99s/it]
# 1 Failed download:
# ['WFC-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10841/11267 [5:16:36<10:28,  1.47s/it]
# 1 Failed download:
# ['WFC-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10842/11267 [5:16:36<07:55,  1.12s/it]
# 1 Failed download:
# ['WFC-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10843/11267 [5:16:37<06:07,  1.15it/s]
# 1 Failed download:
# ['WFC-Q']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10844/11267 [5:16:37<04:55,  1.43it/s]
# 1 Failed download:
# ['WFC-R']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10845/11267 [5:16:37<04:03,  1.73it/s]
# 1 Failed download:
# ['WFC-Y']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  96%|███████████████████████████████████████████████████████████████████████▏  | 10846/11267 [5:16:37<03:28,  2.02it/s]
# 1 Failed download:
# ['WFC-Z']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▋  | 10920/11267 [5:18:40<10:11,  1.76s/it]
# 1 Failed download:
# ['WNNR=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▋  | 10921/11267 [5:18:40<07:39,  1.33s/it]
# 1 Failed download:
# ['WNNR+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▊  | 10937/11267 [5:19:07<09:11,  1.67s/it]
# 1 Failed download:
# ['WRAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▊  | 10940/11267 [5:19:13<11:46,  2.16s/it]
# 1 Failed download:
# ['WRB-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▊  | 10941/11267 [5:19:13<08:41,  1.60s/it]
# 1 Failed download:
# ['WRB-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▊  | 10942/11267 [5:19:14<06:31,  1.21s/it]
# 1 Failed download:
# ['WRB-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▊  | 10943/11267 [5:19:14<05:06,  1.06it/s]
# 1 Failed download:
# ['WRB-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  97%|███████████████████████████████████████████████████████████████████████▉  | 10957/11267 [5:19:40<13:46,  2.67s/it]
# 1 Failed download:
# ['WSO.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  98%|████████████████████████████████████████████████████████████████████████▌ | 11044/11267 [5:21:51<03:50,  1.04s/it]
# 1 Failed download:
# ['XFLT-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  99%|█████████████████████████████████████████████████████████████████████████▎| 11159/11267 [5:24:33<02:11,  1.22s/it]
# 1 Failed download:
# ['YCBD-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 100%|█████████████████████████████████████████████████████████████████████████▋| 11217/11267 [5:25:45<01:15,  1.51s/it]
# 1 Failed download:
# ['ZEV+']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 100%|██████████████████████████████████████████████████████████████████████████| 11267/11267 [5:26:44<00:00,  1.74s/it]
# Total number of valid symbols downloaded = 9815

# %%
valid_data = data_clean[is_valid]
valid_data.to_csv('symbols_valid_meta.csv', index=False)

# %% [markdown]
# ### Crypto

# %%
# List of cryptocurrency symbols
symbols = ["BTC-USD", "ETH-USD", "LTC-USD", "XRP-USD", "BCH-USD", "ADA-USD", "DOT-USD", "LINK-USD", "BNB-USD", "XLM-USD"]

limit = limit if limit else len(symbols)
end = min(offset + limit, len(symbols))
is_valid = [False] * len(symbols)

with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in tqdm(range(offset, end)):
            s = symbols[i]
            data = yf.download(s, period=period)
            if len(data.index) == 0:
                continue
       
            data = optimize_dtypes(data)  
            data = add_all_ta_features_with_exceptions_and_cleanup(data)
            data = add_ticker_to_columns(data, s)

            is_valid[i] = True
            data.to_hdf('crypto/{}.h5'.format(s), key='df', mode='w') 

print('Total number of valid symbols downloaded = {}'.format(sum(is_valid)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:11<00:00,  1.13s/it]
# Total number of valid symbols downloaded = 10

# %% [markdown]
# ## Separating ETFs and Stocks

# %%
# !mkdir stocks
# !mkdir etfs

# %%
etfs = valid_data[valid_data['ETF'] == 'Y']['NASDAQ Symbol'].tolist()
stocks = valid_data[valid_data['ETF'] == 'N']['NASDAQ Symbol'].tolist()

# %%
def move_symbols(symbols, dest):
    for s in symbols:
        filename = '{}.h5'.format(s)
        shutil.move(join('hist', filename), join(dest, filename))
        
move_symbols(etfs, "etfs")
move_symbols(stocks, "stocks")

# %%
! rmdir hist

# %% [markdown]
# ## Train/test split

# %% [markdown]
# ### Stocks

# %%
# !mkdir train
# !mkdir test

# %%
# Path to the directory with the original hdf5 files
directory = "stocks/"

# Path to the directory where you want to save the train/test split files
train_directory = "train/"
test_directory = "test/"

# Iterate over the files in the original directory
for filename in os.listdir(directory):
    if filename.endswith(".h5"):
        # Load the data
        df = pd.read_hdf(os.path.join(directory, filename))
        
        # Skip datasets with fewer than 10 records
        if len(df) < 10:
            print(f"Skipping {filename} due to insufficient data.")
            continue

        # Split the data into a train and test set
        train, test = train_test_split(df, test_size=0.2)

        # Save the train and test sets into new hdf5 files
        train.to_hdf(os.path.join(train_directory, filename), key='train')
        test.to_hdf(os.path.join(test_directory, filename), key='test')

# %% [markdown]
# ### Crypto

# %%
# Path to the directory with the original hdf5 files
directory = "crypto/"

# Path to the directory where you want to save the train/test split files
train_directory = "train/"
test_directory = "test/"

# Iterate over the files in the original directory
for filename in os.listdir(directory):
    if filename.endswith(".h5"):
        # Load the data
        df = pd.read_hdf(os.path.join(directory, filename))

        # Split the data into a train and test set
        train, test = train_test_split(df, test_size=0.2)

        # Save the train and test sets into new hdf5 files
        train.to_hdf(os.path.join(train_directory, filename), key='train')
        test.to_hdf(os.path.join(test_directory, filename), key='test')

# %% [markdown]
# ## Target_day

# %%
df = pd.read_hdf("train/BTC-USD.h5")
df['target_day'] = (df['BTC-USD_Close'].shift(-1) > df['BTC-USD_Close']).astype(int)
df.to_hdf("train/BTC-USD.h5", key='train')

# %%
df = pd.read_hdf("test/BTC-USD.h5")
df['target_day'] = (df['BTC-USD_Close'].shift(-1) > df['BTC-USD_Close']).astype(int)
df.to_hdf("test/BTC-USD.h5", key='test')
